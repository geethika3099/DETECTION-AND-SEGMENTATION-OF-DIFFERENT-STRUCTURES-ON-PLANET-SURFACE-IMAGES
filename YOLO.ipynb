# %% [markdown]
# <a href="https://colab.research.google.com/github/geethika3099/DETECTION-AND-SEGMENTATION-OF-DIFFERENT-STRUCTURES-ON-PLANET-SURFACE-IMAGES/blob/master/YOLO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone  https://github.com/AntonMu/TrainYourOwnYOLO.git
# Out:
# Cloning into 'TrainYourOwnYOLO'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 2266 (delta 1), reused 2 (delta 0), pack-reused 2259
# Receiving objects: 100% (2266/2266), 142.02 MiB | 35.31 MiB/s, done.
# Resolving deltas: 100% (741/741), done.

# %%
# %cd TrainYourOwnYOLO/Data/Source_Images/
# Out:
# /content/TrainYourOwnYOLO/Data/Source_Images

# %%
# !rm -rf Training_Images

# %%
# !rm -rf Test_Images

# %%
# !rm -rf Test_Image_Detection_Results

# %%
# %cd ..
# Out:
# /content/TrainYourOwnYOLO

# %%
# %cd 1_Image_Annotation/
# Out:
# /content/TrainYourOwnYOLO/1_Image_Annotation

# %%
# !python Convert_to_YOLO_format.py

# %%
# %cd ..
# Out:
# /content/TrainYourOwnYOLO

# %%
# %cd 2_Training/
# Out:
# /content/TrainYourOwnYOLO/2_Training

# %%
# !python Download_and_Convert_YOLO_weights.py
# Out:
#  99% (2479879 of 2480070) |############## | Elapsed Time: 0:34:01 ETA:   0:00:00Using TensorFlow backend.
# 2020-05-06 13:12:09.801074: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Loading weights.
# Weights Header:  0 2 0 [32013312]
# Parsing Darknet config.
# Creating Keras model.
# Parsing section net_0
# Parsing section convolutional_0
# conv2d bn leaky (3, 3, 3, 32)
# 2020-05-06 13:12:11.829686: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-06 13:12:11.879926: E tensorflow/stream_executor/cuda/cuda_driver.cc:313] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-05-06 13:12:11.879999: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (58ad42e3dd06): /proc/driver/nvidia/version does not exist
# ...

# %%
# !python Train_YOLO.py
# Out:
# Using TensorFlow backend.
# 2020-05-06 13:16:25.258422: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-05-06 13:16:27.229853: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-06 13:16:27.231695: E tensorflow/stream_executor/cuda/cuda_driver.cc:313] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-05-06 13:16:27.231751: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (58ad42e3dd06): /proc/driver/nvidia/version does not exist
# 2020-05-06 13:16:27.237573: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2300000000 Hz
# 2020-05-06 13:16:27.237816: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x233ebc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# ...

# %%
# %cd ..
# Out:
# /content/TrainYourOwnYOLO

# %%
# %cd 3_Inference/
# Out:
# /content/TrainYourOwnYOLO/3_Inference

# %%
# !pip install keras==2.2.0
# !pip install tensorflow==1.14.0
# Out:
# ...
#      |████████████████████████████████| 307kB 3.4MB/s
# ...
#      |████████████████████████████████| 51kB 6.8MB/s
# ...
# ERROR: tensorflow 2.2.0rc4 has requirement keras-preprocessing>=1.1.0, but you'll have keras-preprocessing 1.0.1 which is incompatible.
# ...
#   Found existing installation: Keras-Preprocessing 1.1.0
#     Uninstalling Keras-Preprocessing-1.1.0:
#       Successfully uninstalled Keras-Preprocessing-1.1.0
#   Found existing installation: Keras-Applications 1.0.8
#     Uninstalling Keras-Applications-1.0.8:
#       Successfully uninstalled Keras-Applications-1.0.8
#   Found existing installation: Keras 2.3.1
#     Uninstalling Keras-2.3.1:
#       Successfully uninstalled Keras-2.3.1
# ...
#      |████████████████████████████████| 109.2MB 1.4MB/s
# ...
#      |████████████████████████████████| 491kB 37.1MB/s
# ...
#      |████████████████████████████████| 51kB 6.3MB/s
# ...
#      |████████████████████████████████| 51kB 6.8MB/s
# ...
#      |████████████████████████████████| 3.2MB 33.5MB/s
# ...

# %%
# !pip install keras-Applications==1.0.4
# Out:
# ...
#      |████████████████████████████████| 51kB 1.6MB/s
# ...
#   Using cached https://files.pythonhosted.org/packages/f8/33/275506afe1d96b221f66f95adba94d1b73f6b6087cfb6132a5655b6fe338/Keras_Preprocessing-1.0.1-py2.py3-none-any.whl
# ...
# ERROR: tensorflow 1.14.0 has requirement keras-applications>=1.0.6, but you'll have keras-applications 1.0.4 which is incompatible.
# ERROR: tensorflow 1.14.0 has requirement keras-preprocessing>=1.0.5, but you'll have keras-preprocessing 1.0.1 which is incompatible.
# ERROR: keras 2.2.0 has requirement keras-applications==1.0.2, but you'll have keras-applications 1.0.4 which is incompatible.
# ...
#   Found existing installation: Keras-Applications 1.0.8
#     Uninstalling Keras-Applications-1.0.8:
#       Successfully uninstalled Keras-Applications-1.0.8
#   Found existing installation: Keras-Preprocessing 1.1.0
#     Uninstalling Keras-Preprocessing-1.1.0:
#       Successfully uninstalled Keras-Preprocessing-1.1.0
# ...

# %%
# !python Detector.py
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...
